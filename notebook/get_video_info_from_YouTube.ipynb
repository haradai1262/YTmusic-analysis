# %%
import os, sys, subprocess, json
import pandas as pd

from apiclient.discovery import build
from apiclient.errors import HttpError
from oauth2client.tools import argparser

# import timeout_decorator
from time import sleep
RETRY = 2

sys.path.append('/secret')
import devkey
DEVELOPER_KEY = devkey.api1
YOUTUBE_API_SERVICE_NAME = "youtube"
YOUTUBE_API_VERSION = "v3"

# connection build
YT = build(YOUTUBE_API_SERVICE_NAME, YOUTUBE_API_VERSION, developerKey=DEVELOPER_KEY)

# %%
# 参考: https://developers.google.com/youtube/v3/docs/videos?hl=ja#resource
infoTree = {
    'id': None,
    'snippet': ['title','description','liveBroadcastContent','tags','publishedAt','thumbnails'],
    'statistics': ['viewCount','likeCount','favoriteCount','dislikeCount','commentCount'],
    'contentDetails':['caption','definition','dimension','duration','projection'],
    'topicDetails':['TopicIds', 'relevantTopicIds'],
}

commentValues = [
'videoId',
'id',
'totalReplyCount',
'authorChannelId',
'authorDisplayName',
'authorProfileImageUrl',
'likeCount',
'publishedAt',
'textOriginal',
'canRate',
'viewerRating'
]

# %%
def get_channel_vlist_quick( yt, cid, max_num ):
    channel_videos_tmp = []
    nextPageToken = ''
    pageNum = 50
    while 1:
        for ridx in range(RETRY):
            try: 
                feed = yt.search().list( channelId=cid, maxResults=pageNum,
                                        order='date', type='video', part='id', pageToken = nextPageToken
                                       ).execute()
                break
            except  Exception as e:
                print( ridx, e, '...' )
                sleep(5)
                continue    
        if ridx == RETRY -1:
            print( 'retry error ...' )
            break
        vids = [ i['id']['videoId'] for i in feed.get('items') ]
        channel_videos_tmp.extend( vids )
        if 'nextPageToken' in feed: nextPageToken = feed[ 'nextPageToken' ]
        else: break
        if len( channel_videos_tmp ) > ( max_num - 60 ): pageNum = ( pageNum / 2 ) + 1
        if len( channel_videos_tmp ) > max_num: break
    return channel_videos_tmp

def get_video_detail( vid ):
    try:
        video_detail = YT.videos().list(part="id,snippet,statistics,contentDetails,topicDetails",id=vid).execute()
        return video_detail.get("items",[])[0]
    except:
        print( 'skipped' )
        return None
        
# @timeout_decorator.timeout(300)
def get_comments_multiplepages( vid, maxNum ):
    comments = []
    nextPageToken = ''
    pageNum = 100
    while 1:
        for ridx in range(RETRY):
            try: 
                commentThreads = YT.commentThreads().list(
                    part="snippet",
                    videoId=vid,
                    maxResults=pageNum,
                    pageToken=nextPageToken,
                    order='relevance',
                    textFormat='plainText'
                ).execute()
                break
            except  Exception as e:
                print( ridx, e, '...' )
                sleep(3)
                continue
        if ridx == RETRY -1:
            print( 'retry error ...' )
            break
        commentsTmp = [ i for i in commentThreads.get('items') ]
        comments.extend( commentsTmp )
        if 'nextPageToken' in commentThreads:
            nextPageToken = commentThreads[ 'nextPageToken' ]
        else:
            break
        if len( comments ) > ( maxNum - 101 ):
            pageNum = ( pageNum / 2 ) + 1
        if len( comments ) > maxNum:
            break
    return comments

def get_comments( vid_tmp ):
    comment_threads = YT.commentThreads().list(
        part="snippet,replies",videoId=vid_tmp,maxResults=100,
        order='relevance',textFormat='plainText' ).execute()
    return comment_threads['items']

def get_rows_comment( comment_info_tmp ):
    rows = []
    for i, com in comment_info_tmp.items():
        # if int(i) % 10000 == 1: print( i )
        try:
            row = [
                com['videoId'],
                com['topLevelComment']['id'],
                com['totalReplyCount'],
                com['topLevelComment']['snippet']['authorChannelId']['value'],
                com['topLevelComment']['snippet']['authorDisplayName'],
                com['topLevelComment']['snippet']['authorProfileImageUrl'],
                com['topLevelComment']['snippet']['likeCount'],
                com['topLevelComment']['snippet']['publishedAt'],
                com['topLevelComment']['snippet']['textOriginal'],
                com['topLevelComment']['snippet']['canRate'],
                com['topLevelComment']['snippet']['viewerRating']
            ]
            rows.append( row )
        except:
            print( com )
            
    return rows

def get_cols( tmp ):
    df_cols_tmp = []
    for parent, child in tmp.items():
        if child == None: df_cols_tmp.append( parent )
        else:
            for c in child: df_cols_tmp.append( c )
    return df_cols_tmp

def get_rows( channel_video_info_tmp, info_tree_tmp ):
    rows = []
    for i, v in channel_video_info_tmp.items():
        # 特定のkeyに値がない場合Noneを入れる
        for parent, child in info_tree_tmp.items():
            if not parent in v:
                v[parent] = {}
                for c in child:
                    v[parent][c] = None
            else:
                if child == None: continue
                for c in child:
                    if not c in v[parent]:
                        v[parent][c] = None
        # 
        row = []
        for parent, child in info_tree_tmp.items():
            if child == None: row.append( v[parent] )
            elif parent == 'snippet':
                for c in child:
                    if c == 'thumbnails':
                        row.append( v[parent][c]['default']['url'] )
                    else:
                        row.append( v[parent][c] )
            else:
                for c in child:
                    row.append( v[parent][c] )
        rows.append( row )
    return rows

# %%
df_channels = pd.read_csv('/data/idol_channels.csv')
channel_id_list = df_channels['channel_id'].values

# %%
save_dir = '/youtube/idol_channels_20191128'
if not os.path.exists( save_dir ): os.mkdir(save_dir)
if not os.path.exists( f'{save_dir}/videos' ): os.mkdir(f'{save_dir}/videos')
if not os.path.exists( f'{save_dir}/comments' ): os.mkdir(f'{save_dir}/comments')

# %%
for cidx, channel_id in enumerate( channel_id_list ):

    print( cidx, channel_id )
    
    channel_dir = f'{save_dir}/videos/{channel_id}'
    if not os.path.exists( channel_dir ):
        os.mkdir(channel_dir)

    channel_videos = get_channel_vlist_quick( YT, channel_id, 500 )
    
    for vidx, vid in enumerate( channel_videos ):
        video_path = f'{channel_dir}/{vid}.json'
        if os.path.exists( video_path ): continue
        vDetail = get_video_detail( vid )
        if vDetail == None: continue
        with open(video_path, 'w') as f:
            json.dump(vDetail, f, indent=4)
# Out:
# 0 UCCRb6nYKaT8tzLA8CwDdUtw
# 1 UCxjXU89x6owat9dA8Z-bzdw
# 2 UCUzpZpX2wRYOk3J8QTFGxDg
# 3 UCmr9bYmymcBmQ1p2tLBRvwg
# 4 UC6YNWTm6zuMFsjqd0PO3G-Q
# 5 UCnhrIe3jZNmqDEL_zSBXADQ
# 6 UCoKXb95K5h3sME3c9OCBaeA
# 7 UCR0V48DJyWbwEAdxLL5FjxA
# 8 UCG-5D9k_fL4FnMeNuraeAtA
# 9 UC8RJBf7ftto2R1EKZC3YE0A
# 10 UCcS2E_TVMSwbN4Q5eH7F_oA
# 11 UCPQ0GEWwLaam1lTX9P-CgGA
# 12 UCDwcZ85zjLKD-3-jqlv1wQQ
# 13 UC6FadPgGviUcq6VQ0CEJqdQ
# 14 UCWBTV02MVmyLqNPWRGDrl6A
# 15 UCLQlkHgD2ltaptlgs20eZ6Q
# 16 UCRkCifCbAw0qwu7XzOa9d7w
# 17 UCQ6Br7m6vP61FZvjv4lwR5w
# 18 UCIfuY0NRq1szr_6tzFy23NQ
# 19 UCw6Y7niyneaJezhnkBSOqkQ
# 20 UCQSWhzO_0ij0GrN7VaZbXcA
# 21 UCv7VutirxDn3RWIJXI68n_A
# 22 UCQuNrURlzPsbJZD17icx7Gw
# 23 UCShhCnBdAL5nYpKrbL9JOTA
# 24 UCt3f_Tu1lNua1xLQZu2Td-w
# 25 UC5GqigDlifXby0ANB8dgT1g
# 26 UCXTsCXNGHmePgo3a47hnsAA
# 27 UCa8GISK9_hsZ8aEJEL1u1Sg
# 28 UCEAn5QItECbYbLW6Mvq3bPg
# 29 UCwFZSxCiCiucEhxtlV4L5Lg
# 30 UCJxYlnZBZc7Ol4FZB9kwl4g
# 31 UCiaowdmU8TziJd9RspD60yQ
# 32 UCkafLPXB6MgLmTbq8UHE8Cg
# 33 UCBmvHfXdGCvi_b6lFeU-E1Q
# 34 UCkEiBC95Yzi7x1pIcdVNiDw
# 35 UCwJDv8UoHrxTCc_10hnEGgw
# 36 UCOEctz8Lhq-mWlXXEC6rCHA
# 37 UC27oEn_SLniRM4FJczDc6nA
# 38 UC8ojUR5waSQVNsEaX06I5yA
# 39 UCsOxECTz2ZK5gGNXHTRaNEg
# 40 UCfqZbR2ReqINXkx6aRkkSWg
# 41 UCLjzHC8I2T99kuxtaaZLaTQ
# 42 UCk2mfF3LamJRjhwGcepMdqQ
# 43 UC0INHFh6fbPsduI1qmXbYrw
# 44 UCp0iCvHGMwyfPHpYq7n2sPw
# 45 UCGt6ZgtDf0Pk2FYXAidDXbg
# 46 UCyvkklnY4CmGyd-C7ocU8qA
# 47 UCXHE7OmSJP4w7wfDXcvw6DQ
# 48 UCi_BYBQrn9bEkH79un6USYQ
# 49 UCSHcJ25cz2HIhROA9DJhOqw
# 50 UCf-muCEo0HUlzsAHQW9JZ_w

# %%
for cidx, channel_id in enumerate( channel_id_list ):

    print( cidx, channel_id )
    channel_dir = f'{save_dir}/comments/{channel_id}'
    if not os.path.exists( channel_dir ): os.mkdir(channel_dir)

    tmp = os.listdir( f'{save_dir}/videos/{channel_id}' )
    vid_list = [ line.split('.')[0] for line in tmp ] 
    for vidx, vid in enumerate( vid_list ):
        
        comment_path = f'{channel_dir}/{vid}.csv'
        if os.path.exists( comment_path  ): continue

        for ridx in range(RETRY):
            try:
                comments = get_comments_multiplepages( vid, 1000 )
                break
            except:
                print( 'timeout ... get_comments_multiplepages()')
                continue
        
        commentInfo = { cidx:com['snippet'] for cidx, com in enumerate( comments ) }
        rows = get_rows_comment( commentInfo )
        df = pd.DataFrame( rows, columns=commentValues )
        df.to_csv( comment_path , index=False  )
        print( 'ok', len( comments ) )
# Out:
# 0 UCCRb6nYKaT8tzLA8CwDdUtw
# ok 863
# ok 1004
# ok 1004
# ok 1050
# ok 1049
# ok 1050
# ok 885
# ok 917
# ok 304
# {'videoId': 'X3H-4crGD6k', 'topLevelComment': {'kind': 'youtube#comment', 'etag': '"j6xRRd8dTPVVptg711_CSPADRfg/42xdiDVbSdHWLkJ_2jSXkDZKW-E"', 'id': 'Ugy2RLlHbOLd6B1Kp6F4AaABAg', 'snippet': {'authorDisplayName': '', 'authorProfileImageUrl': '//s.ytimg.com/yts/img/avatar_32-vflI3ugzv.png', 'authorChannelUrl': '', 'videoId': 'X3H-4crGD6k', 'textDisplay': 'This is 5jackson twice ver', 'textOriginal': 'This is 5jackson twice ver', 'canRate': True, 'viewerRating': 'none', 'likeCount': 0, 'publishedAt': '2019-11-19T11:14:33.000Z', 'updatedAt': '2019-11-19T11:14:33.000Z'}}, 'canReply': True, 'totalReplyCount': 0, 'isPublic': True}
# ok 1004
# 0 <HttpError 400 when requesting https://www.googleapis.com/youtube/v3/commentThreads returned "The API server failed to successfully process the request. While this can be a transient error, it usually indicates that the requests input is invalid. Check the structure of the <code>commentThread</code> resource in the request body to ensure that it is valid."> ...
# retry error ...
# ok 700
# ok 1004
# 0 <HttpError 400 when requesting https://www.googleapis.com/youtube/v3/commentThreads returned "The API server failed to successfully process the request. While this can be a transient error, it usually indicates that the requests input is invalid. Check the structure of the <code>commentThread</code> resource in the request body to ensure that it is valid."> ...
# retry error ...
# ok 500
# ok 1004
# ok 1004
# ok 1004
# ok 578
# ok 1004
# ok 437
# ok 958
# ok 589
# {'videoId': '61yXzdAUdbA', 'topLevelComment': {'kind': 'youtube#comment', 'etag': '"j6xRRd8dTPVVptg711_CSPADRfg/veihXc_ao3KpvjRVmcNrC20v2Ms"', 'id': 'UgzHGOcZ0gi6OZDjKvZ4AaABAg', 'snippet': {'authorDisplayName': '', 'authorProfileImageUrl': '//s.ytimg.com/yts/img/avatar_32-vflI3ugzv.png', 'authorChannelUrl': '', 'videoId': '61yXzdAUdbA', 'textDisplay': "I'd love to see them live....come to the UK!", 'textOriginal': "I'd love to see them live....come to the UK!", 'canRate': True, 'viewerRating': 'none', 'likeCount': 0, 'publishedAt': '2018-06-03T12:05:47.000Z', 'updatedAt': '2018-06-03T12:05:47.000Z'}}, 'canReply': True, 'totalReplyCount': 0, 'isPublic': True}
# ok 1004
# ok 1004
# 0 <HttpError 400 when requesting https://www.googleapis.com/youtube/v3/commentThreads returned "The API server failed to successfully process the request. While this can be a transient error, it usually indicates that the requests input is invalid. Check the structure of the <code>commentThread</code> resource in the request body to ensure that it is valid."> ...
# retry error ...
# ok 100
# ok 504
# ok 1004
# ok 1004
# ok 1004
# ok 1050
# ok 1004
# ok 635
# ok 1004
# ok 1004
# ok 1004
# ok 1004
# ok 1050
# ok 911
# ok 1004
# ok 1004
# ok 1004
# ok 1004
# 0 <HttpError 400 when requesting https://www.googleapis.com/youtube/v3/commentThreads returned "The API server failed to successfully process the request. While this can be a transient error, it usually indicates that the requests input is invalid. Check the structure of the <code>commentThread</code> resource in the request body to ensure that it is valid."> ...
# retry error ...
# ok 700
# ok 1004
# ok 1004
# ok 1004
# ok 1004
# ok 1004
# ok 1004
# ok 1049
# ok 1004
# ok 1004
# 1 UCxjXU89x6owat9dA8Z-bzdw
# ok 586
# ok 13
# ok 30
# 0 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=ggDsEKWY4Iw&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# 1 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=ggDsEKWY4Iw&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# retry error ...
# ok 0
# ok 1
# ok 69
# ok 230
# ok 18
# 0 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=ImVPD6sZDSM&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# 1 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=ImVPD6sZDSM&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# retry error ...
# ok 0
# 0 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=Dh4_nuVyMVA&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# 1 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=Dh4_nuVyMVA&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# retry error ...
# ok 0
# ok 39
# 0 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=flqHG3kZgFM&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# 1 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=flqHG3kZgFM&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# retry error ...
# ok 0
# ok 7
# ok 259
# ok 98
# ok 17
# ok 29
# ok 137
# ok 16
# ok 45
# ok 1004
# ok 31
# ok 83
# ok 1004
# ok 13
# 0 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=7pszadTlY5A&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# 1 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=7pszadTlY5A&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# retry error ...
# ok 0
# ok 92
# ok 146
# ok 599
# ok 63
# ok 46
# 0 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=uqJLNG6uZo4&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# 1 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=uqJLNG6uZo4&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# retry error ...
# ok 0
# ok 61
# 0 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=GafutB7SLVM&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# 1 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=GafutB7SLVM&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# retry error ...
# ok 0
# ok 54
# ok 294
# ok 1004
# 0 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=dfVNk1AWyOY&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# 1 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=dfVNk1AWyOY&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# retry error ...
# ok 0
# ok 733
# 0 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=mN8lgGk2WjI&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# 1 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=mN8lgGk2WjI&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# retry error ...
# ok 0
# ok 35
# 0 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=ZI-TY5ieYfg&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# 1 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=ZI-TY5ieYfg&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# retry error ...
# ok 0
# ok 0
# ok 165
# 0 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=YVdN3Cs2Ljo&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# 1 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=YVdN3Cs2Ljo&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# retry error ...
# ok 0
# 0 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=dFrwj6A8zq4&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# 1 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=dFrwj6A8zq4&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# retry error ...
# ok 0
# ok 74
# ok 1004
# 0 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=wZnfBrfFw14&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# 1 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=wZnfBrfFw14&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# retry error ...
# ok 0
# ok 34
# ok 8
# ok 13
# ok 1004
# ok 73
# ok 88
# 0 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=-sgUSvjypYE&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# 1 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=-sgUSvjypYE&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# retry error ...
# ok 0
# ok 7
# ok 4
# ok 10
# ok 209
# ok 14
# ok 11
# 0 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=u5h6eKxW32c&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# 1 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=u5h6eKxW32c&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# retry error ...
# ok 0
# ok 254
# ok 14
# ok 477
# 0 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=_nLCp6RAwo4&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# 1 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=_nLCp6RAwo4&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# retry error ...
# ok 0
# ok 648
# ok 81
# ok 674
# ok 9
# ok 39
# ok 5
# ok 97
# ok 118
# 0 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=y5gp7gHHkUk&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# 1 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=y5gp7gHHkUk&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# retry error ...
# ok 0
# ok 14
# ok 57
# ok 36
# ok 1004
# ok 12
# ok 40
# ok 9
# ok 19
# ok 1004
# ok 869
# 0 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=uKBAdCY6vKc&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# 1 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=uKBAdCY6vKc&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# retry error ...
# ok 0
# ok 701
# 0 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=0xuqdndttqU&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# 1 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=0xuqdndttqU&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# retry error ...
# ok 0
# ok 358
# ok 80
# ok 20
# ok 569
# ok 255
# ok 613
# ok 4
# ok 130
# ok 22
# ok 50
# 0 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=iluTBJLwv1E&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# 1 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=iluTBJLwv1E&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# retry error ...
# ok 0
# ok 116
# ok 5
# ok 1004
# ok 273
# ok 59
# ok 157
# ok 544
# ok 40
# 0 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=pu6G4OSu_xg&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# 1 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=pu6G4OSu_xg&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# retry error ...
# ok 0
# 0 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=RBP6OBgGtPc&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# 1 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=RBP6OBgGtPc&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# retry error ...
# ok 0
# ok 542
# ok 28
# ok 1004
# ok 12
# ok 73
# ok 627
# ok 220
# 0 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=X4cxbXvjb-Y&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# 1 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=X4cxbXvjb-Y&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# retry error ...
# ok 0
# ok 13
# ok 8
# ok 48
# 0 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=OLcA-U0rw6Y&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# 1 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=OLcA-U0rw6Y&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# retry error ...
# ok 0
# ok 29
# ok 537
# ok 98
# 0 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=Li47EdQkdCM&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# 1 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=Li47EdQkdCM&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# retry error ...
# ok 0
# 0 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=2xZnEvol_qg&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# 1 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=2xZnEvol_qg&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# retry error ...
# ok 0
# ok 1004
# ok 48
# ok 16
# ok 67
# 0 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=GkiKq7Qpk0A&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# 1 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=GkiKq7Qpk0A&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# retry error ...
# ok 0
# 0 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=ZdgH11XDq3s&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# 1 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=ZdgH11XDq3s&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# retry error ...
# ok 0
# ok 20
# ok 2
# ok 14
# 0 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=NmCGzWOpSCk&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# 1 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=NmCGzWOpSCk&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# retry error ...
# ok 0
# ok 32
# ok 119
# ok 5
# ok 134
# ok 1004
# ok 123
# ok 20
# ok 700
# ok 40
# ok 23
# ok 4
# ok 30
# 0 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=IJqIKhf-Dgw&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# 1 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=IJqIKhf-Dgw&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# retry error ...
# ok 0
# ok 1004
# ok 167
# 0 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=x4BkYccVlXY&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# 1 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=x4BkYccVlXY&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# retry error ...
# ok 0
# ok 12
# ok 103
# 0 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=DBIp0NTv26U&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# 1 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=DBIp0NTv26U&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# retry error ...
# ok 0
# ok 42
# ok 55
# ok 176
# 0 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=x6VMK46c4y8&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# 1 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=x6VMK46c4y8&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# retry error ...
# ok 0
# 0 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=SPk0TUJq14I&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# 1 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=SPk0TUJq14I&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# retry error ...
# ok 0
# 0 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=aOqbM04ixu8&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# 1 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=aOqbM04ixu8&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# retry error ...
# ok 0
# ok 237
# 0 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=4boNokOwhVU&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# 1 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=4boNokOwhVU&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# retry error ...
# ok 0
# ok 24
# ok 30
# {'videoId': 'dFf4AgBNR1E', 'topLevelComment': {'kind': 'youtube#comment', 'etag': '"j6xRRd8dTPVVptg711_CSPADRfg/g3gTWnEQNQd94yqaUczAxxGlL0A"', 'id': 'Ugyvvs7HRMUM91bNzXx4AaABAg', 'snippet': {'authorDisplayName': '', 'authorProfileImageUrl': '//s.ytimg.com/yts/img/avatar_32-vflI3ugzv.png', 'authorChannelUrl': '', 'videoId': 'dFf4AgBNR1E', 'textDisplay': '天气之子！', 'textOriginal': '天气之子！', 'canRate': True, 'viewerRating': 'none', 'likeCount': 0, 'publishedAt': '2019-11-13T14:11:36.000Z', 'updatedAt': '2019-11-13T14:11:36.000Z'}}, 'canReply': True, 'totalReplyCount': 0, 'isPublic': True}
# ok 1004
# ok 50
# ok 25
# ok 753
# ok 256
# 0 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=hENnm-llyM4&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# 1 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=hENnm-llyM4&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# retry error ...
# ok 0
# ok 17
# 0 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=FReUJJzzCA8&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# 1 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=FReUJJzzCA8&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# retry error ...
# ok 0
# ok 1
# ok 1004
# ok 129
# ok 1004
# ok 217
# ok 47
# ok 7
# 0 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=qmq5C8UWsS8&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# 1 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=qmq5C8UWsS8&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# retry error ...
# ok 0
# ok 566
# ok 82
# 0 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=bB3CeNWJUqE&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# 1 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=bB3CeNWJUqE&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# retry error ...
# ok 0
# ok 23
# ok 48
# ok 370
# ok 10
# ok 115
# ok 1004
# 0 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=zcOqMZ70FRg&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# 1 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=zcOqMZ70FRg&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# retry error ...
# ok 0
# 0 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=SUoKcDtbPA8&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# 1 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=SUoKcDtbPA8&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# retry error ...
# ok 0
# ok 86
# ok 30
# ok 77
# ok 31
# ok 519
# ok 17
# ok 161
# ok 39
# 0 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=0HjZWzXGAZg&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# 1 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=0HjZWzXGAZg&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# retry error ...
# ok 0
# ok 894
# ok 26
# ok 1004
# ok 82
# ok 46
# 0 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=XzbXkkm7bYc&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# 1 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=XzbXkkm7bYc&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# retry error ...
# ok 0
# 0 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=tOW9XQePPUo&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# 1 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=tOW9XQePPUo&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# retry error ...
# ok 0
# ok 14
# ok 122
# ok 162
# 0 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=iUnHbbHzsbE&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# 1 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=iUnHbbHzsbE&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# retry error ...
# ok 0
# ok 56
# ok 192
# ok 355
# ok 1004
# ok 123
# 0 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=OJLTuwgvSzw&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# 1 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=OJLTuwgvSzw&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# retry error ...
# ok 0
# ok 389
# ok 10
# ok 182
# 0 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=FBNMgUulRo8&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# 1 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=FBNMgUulRo8&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# retry error ...
# ok 0
# ok 5
# 0 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=STm7BcOFwE0&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# 1 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=STm7BcOFwE0&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# retry error ...
# ok 0
# ok 1004
# ok 1004
# ok 47
# ok 1004
# ok 30
# ok 43
# 0 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=ijHsSNMPbu8&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# 1 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=ijHsSNMPbu8&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# retry error ...
# ok 0
# ok 100
# 0 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=_DVUfYs0hXE&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# 1 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=_DVUfYs0hXE&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# retry error ...
# ok 0
# ok 46
# ok 99
# ok 37
# ok 88
# ok 4
# ok 58
# ok 48
# ok 166
# ok 75
# ok 11
# ok 286
# ok 180
# ok 30
# 0 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=LjW4lXiPhlY&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# 1 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=LjW4lXiPhlY&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# retry error ...
# ok 0
# ok 5
# ok 187
# 0 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=j3CqN_MSYi8&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# 1 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=j3CqN_MSYi8&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# retry error ...
# ok 0
# ok 32
# ...
# 1 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=L9QD8tWBEs4&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# retry error ...
# ok 0
# ok 0
# ok 0
# ok 0
# 0 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=qVz5rvIbU4s&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# 1 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=qVz5rvIbU4s&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# retry error ...
# ok 0
# ok 0
# ok 28
# ok 1
# ok 0
# ok 3
# ok 0
# ok 0
# ok 1
# ok 0
# 0 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=gb-QENkJkHM&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# 1 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=gb-QENkJkHM&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# retry error ...
# ok 0
# ok 0
# ok 0
# ok 1
# ok 0
# ok 1
# 0 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=-swVUTXZIBE&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# 1 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=-swVUTXZIBE&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# retry error ...
# ok 0
# ok 0
# ok 2
# ok 0
# ok 0
# ok 0
# ok 0
# ok 0
# ok 4
# ok 0
# ok 0
# ok 2
# ok 0
# ok 1
# ok 0
# ok 0
# ok 0
# ok 1
# ok 0
# ok 0
# ok 0
# ok 0
# ok 1
# ok 2
# ok 1
# ok 1
# ok 0
# ok 0
# ok 0
# ok 0
# ok 5
# 0 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=njWWrHSyQGE&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# 1 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=njWWrHSyQGE&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# retry error ...
# ok 0
# ok 0
# ok 0
# ok 5
# ok 0
# ok 1
# ok 0
# ok 0
# ok 0
# ok 0
# ok 0
# ok 0
# ok 0
# ok 0
# ok 0
# ok 0
# ok 3
# ok 3
# ok 1
# ok 5
# ok 0
# ok 2
# ok 1
# ok 6
# ok 1
# ok 0
# ok 1
# ok 2
# ok 1
# ok 0
# ok 0
# ok 2
# 0 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=0VjiQLbHH7Y&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# 1 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=0VjiQLbHH7Y&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# retry error ...
# ok 0
# ok 0
# ok 0
# ok 0
# ok 0
# ok 0
# ok 0
# ok 2
# ok 2
# ok 1
# ok 0
# ok 0
# 0 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=H445kU_DCYU&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# 1 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=H445kU_DCYU&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# retry error ...
# ok 0
# ok 0
# ok 2
# ok 0
# ok 2
# ok 0
# ok 0
# ok 1
# ok 0
# ok 0
# ok 1
# ok 0
# ok 0
# 0 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=0741Ios1W1w&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# 1 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=0741Ios1W1w&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# retry error ...
# ok 0
# ok 3
# ok 0
# ok 0
# 0 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=xMGj0R8M9x0&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# 1 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=xMGj0R8M9x0&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# retry error ...
# ok 0
# ok 0
# ok 0
# ok 0
# ok 0
# ok 4
# ok 2
# ok 1
# ok 1
# ok 4
# ok 0
# ok 1
# ok 2
# ok 0
# ok 0
# 0 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=x-AAi9i3W1c&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# 1 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=x-AAi9i3W1c&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# retry error ...
# ok 0
# ok 7
# ok 0
# ok 2
# ok 1
# ok 2
# ok 3
# 0 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=N7EGxKyqnIs&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# 1 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=N7EGxKyqnIs&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# retry error ...
# ok 0
# ok 0
# ok 0
# ok 2
# 0 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=syi-tHxE6iU&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# 1 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=syi-tHxE6iU&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# retry error ...
# ok 0
# ok 0
# ok 0
# ok 0
# ok 1
# ok 0
# ok 1
# ok 0
# ok 0
# ok 2
# 49 UCSHcJ25cz2HIhROA9DJhOqw
# 0 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=f6aCSvjT-1w&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# 1 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=f6aCSvjT-1w&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# retry error ...
# ok 0
# 0 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=yUi72LSxGbY&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# 1 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=yUi72LSxGbY&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# retry error ...
# ok 0
# ok 6
# ok 11
# ok 10
# ok 0
# ok 8
# ok 3
# ok 3
# 0 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=FfhDrhIV0jI&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# 1 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=FfhDrhIV0jI&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# retry error ...
# ok 0
# ok 1
# 0 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=E21L7oD53gE&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# 1 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=E21L7oD53gE&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# retry error ...
# ok 0
# ok 4
# ok 30
# 0 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=yaOPi25lP9k&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# 1 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=yaOPi25lP9k&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# retry error ...
# ok 0
# ok 2
# ok 27
# ok 2
# ok 8
# ok 0
# 0 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=mGlsagcxGtY&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# 1 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=mGlsagcxGtY&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# retry error ...
# ok 0
# ok 2
# ok 2
# 0 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=6ijQXCjRjGU&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# 1 <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=6ijQXCjRjGU&maxResults=100&pageToken=&order=relevance&textFormat=plainText&key=AIzaSyDYX2lQvoJEGvExg5yAQQ0ErEac2Bf8h4U&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments."> ...
# retry error ...
# ok 0
# ok 1
# ok 1
# 50 UCf-muCEo0HUlzsAHQW9JZ_w
# ok 7
# ok 14
# ok 41
# ok 8
# ok 12
# ok 16
# ok 5
# ok 26
